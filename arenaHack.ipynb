# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragtyagi2003/story_generator/blob/main/arenaHack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import tensorflow_datasets as tfds

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.9 MB/s eta 0:00:00
# ...

# %%
ds = tfds.load('huggingface:bookcorpusopen/plain_text')
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e8cc1b10d013> in <cell line: 1>()
# ----> 1 ds = tfds.load('huggingface:bookcorpusopen/plain_text')
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     167     metadata = self._start_call()
#     168     try:
# --> 169       return function(*args, **kwargs)
#     170     except Exception:
#     171       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     638       try_gcs,
#     639   )
# --> 640   _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
# ...

# %%
import tensorflow_datasets as tfds

ds = tfds.load('mnist', split='train')
# Out:
# ...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %%
ds = tfds.load('huggingface:bookcorpus/plain_text', split='train')
# Out:
# WARNING:datasets.builder:Found cached dataset bookcorpus (/root/.cache/huggingface/datasets/bookcorpus/plain_text/1.0.0/eddee3cae1cc263a431aa98207d4d27fd8a73b0a9742f692af0e6c65afa4d75f)
# ...
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/bookcorpus/plain_text/1.0.0.incomplete4XRQO1/bookcorpus-train.tfrecord*...…
# Dataset bookcorpus downloaded and prepared to /root/tensorflow_datasets/bookcorpus/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
ds
# Out:
# <_PrefetchDataset element_spec={'text': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# Limit the number of examples to retrieve
num_examples = 100
limited_ds = ds.take(num_examples)

# Iterate over the limited dataset and print the samples
for example in limited_ds:
    text = example['text'].numpy().decode('utf-8')
    print(text)
# Out:
# `` we tell daniel , '' she said .
# if i were sentenced by god himself to spend the rest of my days alone , id still have high standards ; i wouldnt let myself down , especially if all i had were me , and i certainly wouldnt drink my life away , because alcohol is no substitute for anything .
# so what are you going to do , take some seeds and head off into the woods .
# that i could understand .
# `` what would be the fun otherwise ? ''
# distrust hurt , forcibly piercing my happy glow like spikes of ice .
# i frowned as a strong scent of blood reached me .
# i realized that the colorful specks swirling in my line of vision were from staring at a mosaic lamp too intensely .
# how can you still be a virgin ?
# i really do .
# her abduction and their absence at harrington 's party had been explained as a carriage accident , in which angelica had been slightly injured , and for the last two weeks her societal obligations had been limited .
# ...
